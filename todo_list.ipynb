# %% [markdown]
# <h1>Задачи</h1>
#
# 1. Сделать возможность сравнения различных стратегий кросс-валидации (k-fold, leave-one-out)
# 	+ HPOBench
#
# 2. Добавить моделей (сетки)
# 	+ GAM
#
# 3. Добавить эксперименты
# 	+ Rosenbrock
# 	+ Branin
#
# 4. Разные методы оптимизации
#       * ML SURROGATE + OPTUNA ON PREDS
#       * ML SURROGATE + GRID/RANDOM SEARCH ON PREDS
#       * Только OPTUNA без ML SURROGATE
#
# + разные методы в оптуне
#
# 5. Отрефакторить код
#       * класс TargetModel для итретивного получение нового y по x, класс для оптимизации SurrogateModel
#       * убрать локальные функции, унифицировать общую логику для физических и синтетических экспериментов
#       * сделать параметр алгоритма target_value, задаваемый специалистом предметной области для физических экспериментов и равны min(y_all) для синтетических экспериментов
#
#
# 6. График зависимости номера шага от
# |min(y_pred)-global_min(y_true)|
#
# 7. Boxplot для каждого датасета
# по y - число шагов для достижения заданного порога
# по x - модель

# %% [markdown]
# ![image.png](attachment:image.png)
